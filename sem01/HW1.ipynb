# %% [markdown]
# <img src="http://i0.kym-cdn.com/photos/images/original/001/187/255/5e9.gif" width=500>
#
#
# ## Домашка №1: вводимся в python
#
# За домашку можно набрать $100$ баллов. Они будут отнормированы к 10 баллам. Чем сложнее задачка, тем больше она стоит. Если вы ничего не понимаете, а Datacamp особо не помог, можно попытать счастье на http://pythontutor.ru/
#
# Грамотно расчитывайте свои силы и делайте тот объём заданий, который позволит вам получить желаемую оценку :)
#
# ----------------------

# %% [markdown]
# Гендальф приехал! Хоббиты показали ему кучу всего. Реакцию старого волшебника можно найти в шапке тетрадки. Теперь Гендальф сам раздаёт Хоббитам задания.
#
#
# ### Задачка 0 (5 баллов)
#
# Фродо озадачили написать код, который будет выводить только нечётные буквы имени. Чётные буквы должны быть заменены на `?`. Помоги Фродо.
#
# __Пример:__ `Vladimir` -> `V?a?i?i?`

# %%
### ╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ твой код

# %% [markdown]
# ### Задачка 1 (5 баллов)
#
# Сэм получли задание взять чулан с хламом и удалить из него все дубликаты чисел. Помоги Сэму.
#
# __Пример:__  `[1,2,3,3,3,1,2,1,4,1,1,1]` -> `[1,2,3,4]`

# %%
# входные данные
list_in = [1,4,2,3,3,1,1,4,2,1,2,1,3,1,2,3,1,1,4,2,3,4,2,3,5,2,2,3,1,1]

# %%
### ╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ твой код

# %% [markdown]
# ### Задачка 2 (5 баллов)
#
# Мэри выпала задача убрать все дубликаты из строки (в том числе пробелы).
#
# __Пример:__  `Thhhhiiissss iisss vicctttorrryyy!!!` -> `This is victory!`

# %%
str_in = 'Thhhhiiissss iisss vicctttorrryyy!!!'

# %%
### ╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ твой код

# %% [markdown]
# ### Задачка 3 (11 баллов)
#
# Пока Хоббиты решают небольшие задания, Гендальф заннялся рутиной.
#
# Для могущественного магического ритуала Гендальфу нужно быстро подсчитывать площадь своего амулета, который умеет менять размеры. Известно, что амулет имеет форму круга, а Гендальф зает его радиус. Напишите функцию, которая считате площадь амулета по его радиусу. Радиус вводится вне функции.
#
# Посчитайте с помощью этой функции площадь амулетов радиусов $4$, $8$, $15$, $16$, $23$, $42$.
#
#
# __Пример:__
#
# ```python
# [In]  r = 5
#       get_sq(r)
#
# [Out] 78.53981633974483
# ```
#
# __Подсказка:__ Запомнит всяк, кто мыслит туго пи эр квадрат есть площадь круга:
#
# $$
# S = \pi \cdot r^2
# $$

# %%
# используйте эту переменную в качестве значения числа π
from math import pi
pi
# Out:
# 3.141592653589793

# %%
2 * pi # умножили число пи на два
# Out:
# 6.283185307179586

# %%
### ╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ твой код

# %% [markdown]
# ### Задачка 4  (18 баллов)
#
# Пипен не получил задания и подглядывал за тем, как Гендальф колдует. Гендальф заметил это и отправил Пипена разбирать хлам из его повозки.
#
# В повозке лежит лист из листов с числами. Пипен должен разделить все числа на два списка: только положительные и только отрицательные, а затем выяснить где больше элементов и насколко. Помогите ему. Оформите код, который разбивает числа на два списка в виде функции `smash(M)`, которая принимает на вход M и возвращает два листа.
#
# __Пример:__
#
# ```python
# [In]  M = [[1,2][,-1,4]]
#       smash(M)
#
# [Out] [1,2,3], [-1]
# ```
#
# Если не можете оформить код в виде функции, хотябы напишите его. За это тоже будут баллы.

# %%
# входные данные
M = [[8, -9, -6, -9, 10, -8, 1, 7, 5, -2],
     [9, 10, -10, 9, 3, 5, -6, 3, -6, 10],
     [0, 2, 2, 3, -3, -2, -6, 5, 1, -1],
     [-4, 3, -9, -7, -7, 7, -7, 3, 8, -9],
     [1, -10, -2, 6, -10, 4, 1, 8, -3, 4],
     [-2, 8, 10, -9, 10, 0, -8, -5, 2, 0]]

# %%
### ╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ твой код

# %% [markdown]
# ### Задачка 5 (24 балл)
#
# Могущественный древний маг Фибоначчи придумал [волшебные числа.](https://ru.wikipedia.org/wiki/Числа_Фибоначчи) Каждое следующее число Фиббоначи равно сумме двух предыдущих. Первые два числа равны единице. Получается, что
#
# ```
# a_1 = 1
# a_2 = 1
# a_3 = a_2 + a_1 = 1 + 1 = 2
# a_4 = a_3 + a_2 = 2 + 1 = 3
# a_5 = a_4 + a_3 = 3 + 2 = 5
# a_6 = a_5 + a_4 = 5 + 3 = 8
# ...
# ```
#
# Тут `a_i` -  это просто обозначение для $i-$го числа Фибоначчи.
#
# Гендальф очень хочет уметь получать их. Напишите на питоне код, который позволит Гендальфу посчитать $n$-ое число Фибоначчи. Оформите этот код в виде функции от $n$, порядкового номера нужного числа. Убедитесь, что ваш код корректно работает со всеми случаем из примеров ниже.
#
#
# __Примеры:__
#
# ```python
# [In]  fibonacci(5)
# [Out] 5
#
# [In]  fibonacci(10)
# [Out] 55
#
# [In]  fibonacci(3)
# [Out] 2
#
# [In]  fibonacci(2)
# [Out] 1
#
# [In]  fibonacci(1)
# [Out] 1
#
# [In]  fibonacci(40)
# [Out] 102334155
# ```
#
# Если не можете оформить код в виде функции, хотябы напишите его. За это тоже будут баллы.

# %%
### ╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ твой код

# %% [markdown]
# ### Задачка 6 (32 балла)
#
# Пока Хоббиты выполняли поручения Гендальфа, а сам маг пытался добыть древние артефакты и наколдовать колдовство, Бильбо заскучал.
#
# Чтобы как-то развлечь себя, он решил написать для себя функцию, которая принимает на вход строчку из нескольких слов, а затем разворачивает её.
#
# __Пример:__
# ```
# [In]:  'Я есть Грут. Ты нет.'
# [Out]: 'Грут есть я. Нет ты.'
# ```
#
# __Пример:__
# ```
# [In]:  'Мама мыла раму. А папа мыл паркет.'
# [Out]: 'Раму мыла мама. Паркет мыл папа а.'
# ```
#
# Помогите Бильбо. Ваша функция должна учитывать, что:
#
# - в строке предложений может быть несколько
# - предложение начинается с большой буквы
# - кроме слова в начале предложения остальные должны начинаться с маленькой
# - гарантируется отсутствие любых знаков кроме точки в качестве знака препинания

# %%
### ╰( ͡° ͜ʖ ͡° )つ──☆*:・ﾟ твой код

# %% [markdown]
# Настрадался? Выскажи всё, что думаешь обо всём этом [в анонимке по первой домашке.](https://docs.google.com/forms/d/e/1FAIpQLSd5CbwgsK8ujdgwNpu2Un8YNv03to21eIvZFLojB-f-rVeCdw/viewform) Мы прочтём её и сделаем выводы.
